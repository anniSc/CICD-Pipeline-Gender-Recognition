# %%
import os
import subprocess
import pandas as pd
import shutil

# %%
# n = 2000
# df = pd.read_csv(r"C:\Users\busse\Bachelorarbeit\CICD-Pipeline-Gender-Recognition\data\local_image_path_Gender.csv")
# df_sample = df.groupby('Gender', group_keys=False).apply(lambda x: x.sample(n=n, random_state=42))
# df_sample = df_sample.sample(frac=1, random_state=42).reset_index(drop=True)
# df_sample.to_excel(f'C:/Users/busse/Bachelorarbeit/CICD-Pipeline-Gender-Recognition/model/excel_sheets/Gender_{n}.xlsx', index=False)
source_folder = "C:/Users/busse/Bachelorarbeit/CICD-Pipeline-Gender-Recognition/data/img_align_celeba"
# destination_folder = 'C:/Users/busse/Bachelorarbeit/CICD-Pipeline-Gender-Recognition/data/train/'

# %%
import os
import pandas as pd

# Specify the directory you want to use
image_dir = 'C:/Users/busse/Bachelorarbeit/CICD-Pipeline-Gender-Recognition/data/val/men'

# Get a list of all the image files in this directory
image_files = [os.path.join(image_dir, f) for f in os.listdir(image_dir) if os.path.isfile(os.path.join(image_dir, f))]

# Create a DataFrame
df = pd.DataFrame({
    'Images': image_files,
    'Gender': [0]*len(image_files)
})

# Write the DataFrame to a CSV file
df.to_csv('C:/Users/busse/Bachelorarbeit/CICD-Pipeline-Gender-Recognition/model/excel_sheets/image_paths_val_men.csv', index=False)

# %%
df = pd.read_excel(r"C:\Users\busse\Bachelorarbeit\CICD-Pipeline-Gender-Recognition\model\excel_sheets\Gender_1000.xlsx")
df.to_csv(r"C:\Users\busse\Bachelorarbeit\CICD-Pipeline-Gender-Recognition\model\excel_sheets\Gender_1000.csv")

# %%
import os
import pandas as pd

n = 1000
df = pd.read_csv(r"C:\Users\busse\Bachelorarbeit\CICD-Pipeline-Gender-Recognition\data\local_image_path_Gender.csv")

# Zielverzeichnis
destination_folder = 'C:/Users/busse/Bachelorarbeit/CICD-Pipeline-Gender-Recognition/data/val/'
source_folder =  'C:/Users/busse/Bachelorarbeit/CICD-Pipeline-Gender-Recognition/data/img_align_celeba/'
train_folder ='C:/Users/busse/Bachelorarbeit/CICD-Pipeline-Gender-Recognition/data/train/'
# # Filtern Sie die DataFrame, um nur Zeilen zu behalten, deren Bilder nicht im Zielverzeichnis vorhanden sind
df = df[df['Images'].apply(lambda x: not os.path.exists(os.path.join(destination_folder, os.path.basename(x))))]

df_sample = df.groupby('Gender', group_keys=False).apply(lambda x: x.sample(n=n, random_state=42))
df_sample = df_sample.sample(frac=1, random_state=42).reset_index(drop=True)
df_sample.to_excel(f'C:/Users/busse/Bachelorarbeit/CICD-Pipeline-Gender-Recognition/model/excel_sheets/Gender_{n}.xlsx', index=False)

# %%
df_sample
# Out:
#                                                  Images  Gender
# 0     C:/Users/busse/Bachelorarbeit/CICD-Pipeline-Ge...       1
# 1     C:/Users/busse/Bachelorarbeit/CICD-Pipeline-Ge...       0
# 2     C:/Users/busse/Bachelorarbeit/CICD-Pipeline-Ge...       1
# 3     C:/Users/busse/Bachelorarbeit/CICD-Pipeline-Ge...       0
# 4     C:/Users/busse/Bachelorarbeit/CICD-Pipeline-Ge...       1
# ...                                                 ...     ...
# 1995  C:/Users/busse/Bachelorarbeit/CICD-Pipeline-Ge...       1
# 1996  C:/Users/busse/Bachelorarbeit/CICD-Pipeline-Ge...       1
# 1997  C:/Users/busse/Bachelorarbeit/CICD-Pipeline-Ge...       0
# 1998  C:/Users/busse/Bachelorarbeit/CICD-Pipeline-Ge...       1
# 1999  C:/Users/busse/Bachelorarbeit/CICD-Pipeline-Ge...       1
#
# [2000 rows x 2 columns]

# %%
df_train =pd.read_excel("C:/Users/busse/Bachelorarbeit/CICD-Pipeline-Gender-Recognition/model/excel_sheets/Gender_2000.xlsx")
# df_train["Images"] = df_train["Images"].replace("C:/Users/busse/Bachelorarbeit/CICD-Pipeline-Gender-Recognition/data/img_align_celeba//","C:/Users/busse/Bachelorarbeit/CICD-Pipeline-Gender-Recognition/data/train/")
# df_train["Images"] = df_train["Images"].str.replace("\\","/")
df_train["Images"] = df_train["Images"].str.replace("C:/Users/busse/Bachelorarbeit/CICD-Pipeline-Gender-Recognition/data/img_align_celeba//","C:/Users/busse/Bachelorarbeit/CICD-Pipeline-Gender-Recognition/data/train/")

df_train.to_csv( "C:/Users/busse/Bachelorarbeit/CICD-Pipeline-Gender-Recognition/model/excel_sheets/Gender_2000.csv")

# %%
import pandas as pd
import shutil
import os

# Read the CSV file
df_train = pd.read_csv("C:/Users/busse/Bachelorarbeit/CICD-Pipeline-Gender-Recognition/model/excel_sheets/Gender_1000.csv")

# Create the women directory if it doesn't exist
women_dir = "C:/Users/busse/Bachelorarbeit/CICD-Pipeline-Gender-Recognition/data/val/women"
os.makedirs(women_dir, exist_ok=True)

# Iterate over the dataframe
for index, row in df_train.iterrows():
    # If the label is 0, move the image to the women directory
    if row['Gender'] == 0:
        # Construct the source and destination paths
        src_path = row['Images']
        dst_path = os.path.join(women_dir, os.path.basename(src_path))
        
        # Move the file
        shutil.move(src_path, dst_path)

# %%
df_sample['Images'] = df_sample['Images'].str.replace('\\', '/')
# df_sample['Images'] = df_sample['Images'].str.replace('C:/Users/busse/Bachelorarbeit/CICD-Pipeline-Gender-Recognition/', '')
file_names = df_sample['Images'].tolist()
print(file_names)
# Out:
# ['C:/Users/busse/Bachelorarbeit/CICD-Pipeline-Gender-Recognition/data/img_align_celeba/100480.jpg', 'C:/Users/busse/Bachelorarbeit/CICD-Pipeline-Gender-Recognition/data/img_align_celeba/027760.jpg', 'C:/Users/busse/Bachelorarbeit/CICD-Pipeline-Gender-Recognition/data/img_align_celeba/164147.jpg', 'C:/Users/busse/Bachelorarbeit/CICD-Pipeline-Gender-Recognition/data/img_align_celeba/099579.jpg', 'C:/Users/busse/Bachelorarbeit/CICD-Pipeline-Gender-Recognition/data/img_align_celeba/120732.jpg', 'C:/Users/busse/Bachelorarbeit/CICD-Pipeline-Gender-Recognition/data/img_align_celeba/096755.jpg', 'C:/Users/busse/Bachelorarbeit/CICD-Pipeline-Gender-Recognition/data/img_align_celeba/200021.jpg', 'C:/Users/busse/Bachelorarbeit/CICD-Pipeline-Gender-Recognition/data/img_align_celeba/020104.jpg', 'C:/Users/busse/Bachelorarbeit/CICD-Pipeline-Gender-Recognition/data/img_align_celeba/189639.jpg', 'C:/Users/busse/Bachelorarbeit/CICD-Pipeline-Gender-Recognition/data/img_align_celeba/030702.jpg', 'C:/Use
# ...

# %%
selected_image_paths = [os.path.join(source_folder, file) for file in file_names]

# %%
files1 = set(os.listdir(destination_folder))
files2 = set(os.listdir(train_folder))
if files1 == files2:
    print("Die Ordner enthalten die gleichen Dateien.")
else:
    print("Die Ordner enthalten nicht die gleichen Dateien.")
# Out:
# Die Ordner enthalten nicht die gleichen Dateien.

# %%
for image_path in selected_image_paths:
     if os.path.exists(image_path):
        print(image_path)
        shutil.copy(image_path, destination_folder)
# Out:
# C:/Users/busse/Bachelorarbeit/CICD-Pipeline-Gender-Recognition/data/img_align_celeba/100480.jpg
# C:/Users/busse/Bachelorarbeit/CICD-Pipeline-Gender-Recognition/data/img_align_celeba/027760.jpg
# C:/Users/busse/Bachelorarbeit/CICD-Pipeline-Gender-Recognition/data/img_align_celeba/164147.jpg
# C:/Users/busse/Bachelorarbeit/CICD-Pipeline-Gender-Recognition/data/img_align_celeba/099579.jpg
# C:/Users/busse/Bachelorarbeit/CICD-Pipeline-Gender-Recognition/data/img_align_celeba/120732.jpg
# C:/Users/busse/Bachelorarbeit/CICD-Pipeline-Gender-Recognition/data/img_align_celeba/096755.jpg
# C:/Users/busse/Bachelorarbeit/CICD-Pipeline-Gender-Recognition/data/img_align_celeba/200021.jpg
# C:/Users/busse/Bachelorarbeit/CICD-Pipeline-Gender-Recognition/data/img_align_celeba/020104.jpg
# C:/Users/busse/Bachelorarbeit/CICD-Pipeline-Gender-Recognition/data/img_align_celeba/189639.jpg
# C:/Users/busse/Bachelorarbeit/CICD-Pipeline-Gender-Recognition/data/img_align_celeba/030702.jpg
# ...
